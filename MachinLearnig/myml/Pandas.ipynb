# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("./datasets/titanic.csv")

# %%
titanic.iloc[0:5,0]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: PassengerId, dtype: int64

# %%
titanic.loc[titanic["Age"] < 1.0, "Cabin"] = "None"

# %%
titanic.loc[titanic["Cabin"]=="None", :]
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 78            79         1       2    Caldwell, Master. Alden Gates    male
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 469          470         1       3    Baclini, Miss. Helene Barbara  female
# 644          645         1       3           Baclini, Miss. Eugenie  female
# 755          756         1       2        Hamalainen, Master. Viljo    male
# 803          804         1       3  Thomas, Master. Assad Alexander    male
# 831          832         1       2  Richards, Master. George Sibley    male
#
#       Age  SibSp  Parch  Ticket      Fare Cabin Embarked
# 78   0.83      0      2  248738   29.0000  None        S
# 305  0.92      1      2  113781  151.5500  None        S
# 469  0.75      2      1    2666   19.2583  None        C
# 644  0.75      2      1    2666   19.2583  None        C
# 755  0.67      1      1  250649   14.5000  None        S
# 803  0.42      0      1    2625    8.5167  None        C
# 831  0.83      1      1   29106   18.7500  None        S

# %%
df = titanic.select_dtypes(include=["float64"])
df
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
def f1(x):
    print(type(x))
    return x.max() - x.min()

# %%
df.apply(f1)
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.series.Series'>
# Age      79.5800
# Fare    512.3292
# dtype: float64

# %%
def f2(x):
    
    return x

# %%
df["Age2"] = df["Age"].apply(f2)
# Out:
# 22.0
# 38.0
# 26.0
# 35.0
# 35.0
# nan
# 54.0
# 2.0
# 27.0
# 14.0
# 4.0
# 58.0
# 20.0
# 39.0
# 14.0
# 55.0
# 2.0
# nan
# 31.0
# nan
# 35.0
# 34.0
# 15.0
# 28.0
# 8.0
# 38.0
# nan
# 19.0
# nan
# nan
# 40.0
# nan
# nan
# 66.0
# 28.0
# 42.0
# nan
# 21.0
# 18.0
# 14.0
# 40.0
# 27.0
# nan
# 3.0
# 19.0
# nan
# nan
# nan
# nan
# 18.0
# 7.0
# 21.0
# 49.0
# 29.0
# 65.0
# nan
# 21.0
# 28.5
# 5.0
# 11.0
# 22.0
# 38.0
# 45.0
# 4.0
# nan
# nan
# 29.0
# 19.0
# 17.0
# 26.0
# 32.0
# 16.0
# 21.0
# 26.0
# 32.0
# 25.0
# nan
# nan
# 0.83
# 30.0
# 22.0
# 29.0
# nan
# 28.0
# 17.0
# 33.0
# 16.0
# nan
# 23.0
# 24.0
# 29.0
# 20.0
# 46.0
# 26.0
# 59.0
# nan
# 71.0
# 23.0
# 34.0
# 34.0
# 28.0
# nan
# 21.0
# 33.0
# 37.0
# 28.0
# 21.0
# nan
# 38.0
# nan
# 47.0
# 14.5
# 22.0
# 20.0
# 17.0
# 21.0
# 70.5
# 29.0
# 24.0
# 2.0
# 21.0
# nan
# 32.5
# 32.5
# 54.0
# 12.0
# nan
# 24.0
# nan
# 45.0
# 33.0
# 20.0
# 47.0
# 29.0
# 25.0
# 23.0
# 19.0
# 37.0
# 16.0
# 24.0
# nan
# 22.0
# 24.0
# 19.0
# 18.0
# 19.0
# 27.0
# 9.0
# 36.5
# 42.0
# 51.0
# 22.0
# 55.5
# 40.5
# nan
# 51.0
# 16.0
# 30.0
# nan
# nan
# 44.0
# 40.0
# 26.0
# 17.0
# 1.0
# 9.0
# nan
# 45.0
# nan
# 28.0
# 61.0
# 4.0
# 1.0
# 21.0
# 56.0
# 18.0
# nan
# 50.0
# 30.0
# 36.0
# nan
# nan
# 9.0
# 1.0
# 4.0
# nan
# nan
# 45.0
# 40.0
# 36.0
# 32.0
# 19.0
# 19.0
# 3.0
# 44.0
# 58.0
# nan
# 42.0
# nan
# 24.0
# 28.0
# nan
# 34.0
# 45.5
# 18.0
# 2.0
# 32.0
# 26.0
# 16.0
# 40.0
# 24.0
# 35.0
# 25.0
# 39.0
# 49.0
# 31.0
# 30.0
# 30.0
# 34.0
# 31.0
# 11.0
# 0.42
# 27.0
# 31.0
# 39.0
# 18.0
# 39.0
# 33.0
# 26.0
# 39.0
# 35.0
# 6.0
# 30.5
# nan
# 23.0
# 31.0
# 43.0
# 10.0
# 52.0
# 27.0
# 38.0
# 27.0
# 2.0
# nan
# nan
# 1.0
# nan
# 62.0
# 15.0
# 0.83
# nan
# 23.0
# 18.0
# 39.0
# 21.0
# nan
# 32.0
# nan
# 20.0
# 16.0
# 30.0
# 34.5
# 17.0
# 42.0
# nan
# 35.0
# 28.0
# nan
# 4.0
# 74.0
# 9.0
# 16.0
# 44.0
# 18.0
# 45.0
# 51.0
# 24.0
# nan
# 41.0
# 21.0
# 48.0
# nan
# 24.0
# 42.0
# 27.0
# 31.0
# nan
# 4.0
# 26.0
# 47.0
# 33.0
# 47.0
# 28.0
# 15.0
# 20.0
# 19.0
# nan
# 56.0
# 25.0
# 33.0
# 22.0
# 28.0
# 25.0
# 39.0
# 27.0
# 19.0
# nan
# 26.0
# 32.0
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
def f3(x):
    if x == 'male':
        return 1
    else:
        return 0

# %%
titanic.Sex = titanic.Sex.apply(f3)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
titanic["Survived"]=titanic["Survived"].apply(lambda x :'saved' if x == 1 else 'lost')
titanic.head()
# Out:
#    PassengerId Survived  Pclass  \
# 0            1     lost       3
# 1            2    saved       1
# 2            3    saved       3
# 3            4    saved       1
# 4            5     lost       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
titanic["Survived"]=titanic["Survived"].map({"saved":0, "lost":1})
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       NaN       3
# 1            2       NaN       1
# 2            3       NaN       3
# 3            4       NaN       1
# 4            5       NaN       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
titanic.isnull().sum(axis=0)
# Out:
# PassengerId      0
# Survived       891
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         2
# dtype: int64

# %%
x = titanic.dropna()
x.shape
# Out:
# (0, 12)

# %%
x = titanic.fillna(0)
x.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       0.0       1
# 2            3       0.0       3
# 3            4       0.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       0.0       3
# 9           10       0.0       2
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
# 5                                   Moran, Mr. James    1   0.0      0      0
# 6                            McCarthy, Mr. Timothy J    1  54.0      0      0
# 7                     Palsson, Master. Gosta Leonard    1   2.0      3      1
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)    0  27.0      0      2
# 9                Nasser, Mrs. Nicholas (Adele Achem)    0  14.0      1      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500     0        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250     0        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500     0        S
# 5            330877   8.4583     0        Q
# 6             17463  51.8625   E46        S
# 7            349909  21.0750     0        S
# 8            347742  11.1333     0        S
# 9            237736  30.0708     0        C

# %%
titanic["Age"].mean()
# Out:
# 29.69911764705882

# %%
titanic["Age"]=titanic["Age"].fillna(titanic["Age"].mean())
titanic.isna().sum(axis=0)
# Out:
# PassengerId      0
# Survived       891
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         2
# dtype: int64

# %%
titanic["Embarked"].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
titanic["Embarked"]=titanic["Embarked"].fillna("S")
titanic.isna().sum(axis=0)
# Out:
# PassengerId      0
# Survived       891
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          681
# Embarked         0
# dtype: int64

# %%
titanic.drop(["Cabin"], axis=1, inplace=True)

# %%
titanic["Embarked"].value_counts()
# Out:
# S    646
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
sr = titanic["Embarked"].value_counts()

# %%
plt.bar(sr.index, sr.values)
plt.show()

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       NaN       3
# 1            2       NaN       1
# 2            3       NaN       3
# 3            4       NaN       1
# 4            5       NaN       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
#남성 승객의 나이 평균
titanic.loc[titanic["Sex"]== 1, "Age"].mean()
# Out:
# 30.505824243042102

# %%
#여성 승객의 나이 평균
titanic.loc[titanic["Sex"]== 0, "Age"].mean()
# Out:
# 28.21673004870738

# %% [markdown]
# ## GroupBy

# %%
data = {
    'city' : ['Busan', 'Busan', 'Busan','Busan', 'Seoul','Seoul','Seoul'],
    'fruit':['Apple', 'Orange', 'Banana', 'Banana', 'Apple', 'Apple', 'Banana'],
    'price':[100, 200, 250, 300, 150, 200, 400],
    'quantity':[1, 2, 3, 4, 5, 6, 7]
}

df = pd.DataFrame(data)
df
# Out:
#     city   fruit  price  quantity
# 0  Busan   Apple    100         1
# 1  Busan  Orange    200         2
# 2  Busan  Banana    250         3
# 3  Busan  Banana    300         4
# 4  Seoul   Apple    150         5
# 5  Seoul   Apple    200         6
# 6  Seoul  Banana    400         7

# %%
df.groupby('city').price.mean()

# %%
df.groupby(['city', 'fruit']).mean()
# Out:
#               price  quantity
# city  fruit
# Busan Apple   100.0       1.0
#       Banana  275.0       3.5
#       Orange  200.0       2.0
# Seoul Apple   175.0       5.5
#       Banana  400.0       7.0

# %%
titanic.groupby('Sex').Age.mean()
# Out:
# Sex
# 0    28.216730
# 1    30.505824
# Name: Age, dtype: float64

# %% [markdown]
# ## 연속형 데이터를 범주형으로

# %%
titanic["AgeClass"] = pd.cut(titanic['Age'], 3, labels = ['child', 'young', 'old'])
titanic.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/myml/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/envs/myml/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/myml/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [80], in <cell line: 1>()
# ----> 1 titanic["AgeClass"] = pd.cut(titanic['Age'], 3, labels = ['child', 'young', 'old'])
#       2 titanic.head()
#
# File ~/opt/anaconda3/envs/myml/lib/python3.8/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/myml/lib/python3.8/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'Age'

# %%
titanic["AgeClass"].value_counts()
# Out:
# young    522
# child    319
# old       50
# Name: AgeClass, dtype: int64

# %%
titanic = titanic.drop(['Age'], axis=1)
titanic.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [82], in <cell line: 1>()
# ----> 1 titanic = titanic.drop(['Age'], axis=1)
#       2 titanic.head()
#
# File ~/opt/anaconda3/envs/myml/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/myml/lib/python3.8/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~/opt/anaconda3/envs/myml/lib/python3.8/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~/opt/anaconda3/envs/myml/lib/python3.8/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~/opt/anaconda3/envs/myml/lib/python3.8/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Age'] not found in axis"

# %%
 data = {
        "Dave":"dave@gmail.com",
        "Steve":"steve@naver.com",
        "Rob":"rob@gmail.com",
        "Wes":"wes@hanmail.net"
    }

# %%
sr = pd.Series(data)

sr
# Out:
# Dave      dave@gmail.com
# Steve    steve@naver.com
# Rob        rob@gmail.com
# Wes      wes@hanmail.net
# dtype: object

# %%
sr.str.findall('^[a-zA-Z0-9+-\_.]+@[a-zA-Z0-9-]+\.[a-zA-Z0-9-.]+$')
# Out:
# Dave      [dave@gmail.com]
# Steve    [steve@naver.com]
# Rob        [rob@gmail.com]
# Wes      [wes@hanmail.net]
# dtype: object

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       NaN       3
# 1            2       NaN       1
# 2            3       NaN       3
# 3            4       NaN       1
# 4            5       NaN       3
#
#                                                 Name  Sex  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0      1      0
# 2                             Heikkinen, Miss. Laina    0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0      1      0
# 4                           Allen, Mr. William Henry    1      0      0
#
#              Ticket     Fare Embarked AgeClass
# 0         A/5 21171   7.2500        S    child
# 1          PC 17599  71.2833        C    young
# 2  STON/O2. 3101282   7.9250        S    child
# 3            113803  53.1000        S    young
# 4            373450   8.0500        S    young

# %% [markdown]
# ## 시계열

# %%
data = np.random.randn(1000, 3)
data.shape

df = pd.DataFrame(data,
            index=pd.date_range('1/1/2022', periods=1000),
            columns = ['A', 'B', 'C'])

# %%
data.head(10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [96], in <cell line: 1>()
# ----> 1 data.head(10)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
df.head(10)
# Out:
#                    A         B         C
# 2022-01-01 -1.472378 -1.886012  1.770699
# 2022-01-02 -0.641813 -2.277383  1.474034
# 2022-01-03  1.665843  0.310882  0.604790
# 2022-01-04  0.836131  0.885136 -1.702681
# 2022-01-05  1.709821  1.430828  0.359199
# 2022-01-06  0.977095 -0.057039 -0.033589
# 2022-01-07  0.106423 -1.197808  0.885474
# 2022-01-08 -0.514685 -0.920078  0.763066
# 2022-01-09  1.043603 -0.566738  0.132105
# 2022-01-10  2.353532 -0.103494  1.153003
