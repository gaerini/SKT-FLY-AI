# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## train data preprocessing

# %%
train = pd.read_csv("./DACONLG/train.csv")

# %%
train.head()
# Out:
#             ID    X_01     X_02   X_03  X_04     X_05    X_06   X_07    X_08  \
# 0  TRAIN_00001  70.544  103.320  67.47     1  101.892  74.983  29.45   62.38
# 1  TRAIN_00002  69.524  103.321  65.17     1  101.944  72.943  28.73   61.23
# 2  TRAIN_00003  72.583  103.320  64.07     1  103.153  72.943  28.81  105.77
# 3  TRAIN_00004  71.563  103.320  67.57     1  101.971  77.022  28.92  115.21
# 4  TRAIN_00005  69.524  103.320  63.57     1  101.981  70.904  29.68  103.38
#
#      X_09  ...    Y_05    Y_06   Y_07    Y_08    Y_09    Y_10    Y_11    Y_12  \
# 0  245.71  ...  29.632  16.083  4.276 -25.381 -25.529 -22.769  23.792 -25.470
# 1  233.61  ...  33.179  16.736  3.229 -26.619 -26.523 -22.574  24.691 -26.253
# 2  272.20  ...  31.801  17.080  2.839 -26.238 -26.216 -22.169  24.649 -26.285
# 3  255.36  ...  34.503  17.143  3.144 -25.426 -25.079 -21.765  24.913 -25.254
# 4  241.46  ...  32.602  17.569  3.138 -25.376 -25.242 -21.072  25.299 -25.072
#
#      Y_13    Y_14
# ...

# %%
train = train.drop(['ID'], axis=1)
train.head()
# Out:
#      X_01     X_02   X_03  X_04     X_05    X_06   X_07    X_08    X_09  X_10  \
# 0  70.544  103.320  67.47     1  101.892  74.983  29.45   62.38  245.71   0.0
# 1  69.524  103.321  65.17     1  101.944  72.943  28.73   61.23  233.61   0.0
# 2  72.583  103.320  64.07     1  103.153  72.943  28.81  105.77  272.20   0.0
# 3  71.563  103.320  67.57     1  101.971  77.022  28.92  115.21  255.36   0.0
# 4  69.524  103.320  63.57     1  101.981  70.904  29.68  103.38  241.46   0.0
#
#    ...    Y_05    Y_06   Y_07    Y_08    Y_09    Y_10    Y_11    Y_12    Y_13  \
# 0  ...  29.632  16.083  4.276 -25.381 -25.529 -22.769  23.792 -25.470 -25.409
# 1  ...  33.179  16.736  3.229 -26.619 -26.523 -22.574  24.691 -26.253 -26.497
# 2  ...  31.801  17.080  2.839 -26.238 -26.216 -22.169  24.649 -26.285 -26.215
# 3  ...  34.503  17.143  3.144 -25.426 -25.079 -21.765  24.913 -25.254 -25.021
# 4  ...  32.602  17.569  3.138 -25.376 -25.242 -21.072  25.299 -25.072 -25.195
#
#      Y_14
# 0 -25.304
# ...

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39607 entries, 0 to 39606
# Data columns (total 70 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   X_01    39607 non-null  float64
#  1   X_02    39607 non-null  float64
#  2   X_03    39607 non-null  float64
#  3   X_04    39607 non-null  int64
#  4   X_05    39607 non-null  float64
#  5   X_06    39607 non-null  float64
#  6   X_07    39607 non-null  float64
#  7   X_08    39607 non-null  float64
#  8   X_09    39607 non-null  float64
#  9   X_10    39607 non-null  float64
#  10  X_11    39607 non-null  float64
#  11  X_12    39607 non-null  float64
#  12  X_13    39607 non-null  float64
#  13  X_14    39607 non-null  float64
#  14  X_15    39607 non-null  float64
#  15  X_16    39607 non-null  float64
#  16  X_17    39607 non-null  float64
#  17  X_18    39607 non-null  float64
#  18  X_19    39607 non-null  float64
#  19  X_20    39607 non-null  float64
# ...

# %%
sns.heatmap(train.corr())
# Out:
# <AxesSubplot:>

# %%
train["X_04"].unique(), train["X_23"].unique(), train["X_46"].unique(), train["X_47"].unique(), train["X_48"].unique()
# Out:
# (array([1]),
#  array([1]),
#  array([1463, 1468, 1469, 1467, 1465, 1462, 1464, 1460, 1461, 1457, 1466,
#         1459, 1458]),
#  array([1]),
#  array([1]))

# %%
train["X_10"].value_counts()
# Out:
# 0.0    39575
# 2.9       12
# 3.0       12
# 3.3        4
# 3.1        2
# 3.6        1
# 3.2        1
# Name: X_10, dtype: int64

# %%
X_train = train.iloc[:, :56]
X_train = X_train.drop(["X_04", "X_23", "X_47", "X_48"], axis=1)
X_train.head()
# Out:
#      X_01     X_02   X_03     X_05    X_06   X_07    X_08    X_09  X_10  X_11  \
# 0  70.544  103.320  67.47  101.892  74.983  29.45   62.38  245.71   0.0   0.0
# 1  69.524  103.321  65.17  101.944  72.943  28.73   61.23  233.61   0.0   0.0
# 2  72.583  103.320  64.07  103.153  72.943  28.81  105.77  272.20   0.0   0.0
# 3  71.563  103.320  67.57  101.971  77.022  28.92  115.21  255.36   0.0   0.0
# 4  69.524  103.320  63.57  101.981  70.904  29.68  103.38  241.46   0.0   0.0
#
#    ...  X_45  X_46      X_49        X_50        X_51        X_52        X_53  \
# 0  ...  0.29  1463   9706.03  137.043591  135.359219  147.837968  134.313475
# 1  ...  0.13  1463  10423.43  133.736691  135.979817  149.924692  123.630583
# 2  ...  0.14  1468  10948.53  132.805112  131.055355  146.814592  128.939070
# 3  ...  0.22  1469  15007.03  134.138760  133.239422  139.720132  132.260824
# 4  ...  0.22  1469  11051.03  142.728970  136.620022  134.853555  134.760252
#
# ...

# %%
y_train = train.iloc[:, 56:]
y_train.shape
# Out:
# (39607, 14)

# %% [markdown]
# ## test data preprocessing

# %%
test = pd.read_csv("./DACONLG/test.csv")
test.head()
# Out:
#            ID    X_01     X_02   X_03  X_04     X_05    X_06   X_07    X_08  \
# 0  TEST_00001  68.504  103.321  76.67     1  101.867  73.963  30.51   63.57
# 1  TEST_00002  67.485  103.320  69.37     1  101.992  67.845  28.03  116.99
# 2  TEST_00003  69.524  103.320  68.97     1  101.884  77.022  29.65  205.68
# 3  TEST_00004  69.524  103.320  65.87     1  101.866  73.963  28.15  103.38
# 4  TEST_00005  73.603  103.321  66.67     1  101.891  74.983  29.92   71.20
#
#      X_09  ...  X_47  X_48      X_49        X_50        X_51        X_52  \
# 0  239.80  ...     1     1  17227.63  138.130429  129.460682  141.506570
# 1  189.23  ...     1     1  17134.53  136.148839  128.266277  145.911745
# 2  214.93  ...     1     1  14860.83  120.447446  119.988804  132.099908
# 3  180.80  ...     1     1  15252.53  133.994695  125.069180  147.507669
# 4  231.93  ...     1     1  10752.23  137.918202  135.116192  138.600473
#
#          X_53        X_54        X_55        X_56
# ...

# %%
X_test = test.drop(['ID'], axis=1)
X_test.head()
# Out:
#      X_01     X_02   X_03  X_04     X_05    X_06   X_07    X_08    X_09  X_10  \
# 0  68.504  103.321  76.67     1  101.867  73.963  30.51   63.57  239.80   0.0
# 1  67.485  103.320  69.37     1  101.992  67.845  28.03  116.99  189.23   0.0
# 2  69.524  103.320  68.97     1  101.884  77.022  29.65  205.68  214.93   0.0
# 3  69.524  103.320  65.87     1  101.866  73.963  28.15  103.38  180.80   0.0
# 4  73.603  103.321  66.67     1  101.891  74.983  29.92   71.20  231.93   0.0
#
#    ...  X_47  X_48      X_49        X_50        X_51        X_52        X_53  \
# 0  ...     1     1  17227.63  138.130429  129.460682  141.506570  133.427229
# 1  ...     1     1  17134.53  136.148839  128.266277  145.911745  131.196417
# 2  ...     1     1  14860.83  120.447446  119.988804  132.099908  120.450155
# 3  ...     1     1  15252.53  133.994695  125.069180  147.507669  123.142653
# 4  ...     1     1  10752.23  137.918202  135.116192  138.600473  127.173033
#
# ...

# %%
X_test = X_test.drop(["X_04", "X_23", "X_47", "X_48"], axis=1)
X_test.head()
# Out:
#      X_01     X_02   X_03     X_05    X_06   X_07    X_08    X_09  X_10  X_11  \
# 0  68.504  103.321  76.67  101.867  73.963  30.51   63.57  239.80   0.0   0.0
# 1  67.485  103.320  69.37  101.992  67.845  28.03  116.99  189.23   0.0   0.0
# 2  69.524  103.320  68.97  101.884  77.022  29.65  205.68  214.93   0.0   0.0
# 3  69.524  103.320  65.87  101.866  73.963  28.15  103.38  180.80   0.0   0.0
# 4  73.603  103.321  66.67  101.891  74.983  29.92   71.20  231.93   0.0   0.0
#
#    ...  X_45  X_46      X_49        X_50        X_51        X_52        X_53  \
# 0  ...  0.16  1469  17227.63  138.130429  129.460682  141.506570  133.427229
# 1  ...  0.27  1462  17134.53  136.148839  128.266277  145.911745  131.196417
# 2  ...  0.14  1469  14860.83  120.447446  119.988804  132.099908  120.450155
# 3  ...  0.13  1469  15252.53  133.994695  125.069180  147.507669  123.142653
# 4  ...  0.09  1469  10752.23  137.918202  135.116192  138.600473  127.173033
#
# ...

# %% [markdown]
# ## Data Scaling
# train데이터를 fit한 것을 가지고 test 데이터에 transform시켜야한다. 그리고 y는 일반적으로 스케일링하지 않는다.

# %%
from sklearn.preprocessing import MinMaxScaler

mms = MinMaxScaler()

# %%
X_train_scaled = mms.fit_transform(X_train)
X_train_scaled.shape
# Out:
# (39607, 52)

# %%
X_test_scaled = mms.transform(X_test)
X_test_scaled.shape
# Out:
# (39608, 52)

# %%
y_train_01 = y_train.iloc[:, 0]
y_train_02 = y_train.iloc[:, 1]
y_train_03 = y_train.iloc[:, 2]
y_train_04 = y_train.iloc[:, 3]
y_train_05 = y_train.iloc[:, 4]
y_train_06 = y_train.iloc[:, 5]
y_train_07 = y_train.iloc[:, 6]
y_train_08 = y_train.iloc[:, 7]
y_train_09 = y_train.iloc[:, 8]
y_train_10 = y_train.iloc[:, 9]
y_train_11 = y_train.iloc[:, 10]
y_train_12 = y_train.iloc[:, 11]
y_train_13 = y_train.iloc[:, 12]
y_train_14 = y_train.iloc[:, 13]
y_train_01.shape
# Out:
# (39607,)

# %%
from xgboost import XGBRegressor

model = XGBRegressor()

# %%
model.fit(X_train_scaled, y_train_01)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.300000012,
#              max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_test_01 = model.predict(X_test_scaled)
y_test_01[:10]
# Out:
# array([1.524816 , 1.4933614, 1.5737749, 1.4444864, 1.2793778, 1.5428765,
#        1.3300341, 1.4021379, 1.3368655, 1.3483313], dtype=float32)

# %%
model.fit(X_train_scaled, y_train_02)
y_test_02 = model.predict(X_test_scaled)
y_test_02[:10]
# Out:
# array([1.3608282 , 1.2064742 , 0.91767114, 1.0951807 , 1.0794004 ,
#        0.9976357 , 1.2960899 , 1.4086889 , 1.1103798 , 0.89748186],
#       dtype=float32)

# %%
model.fit(X_train_scaled, y_train_03)
y_test_03 = model.predict(X_test_scaled)
y_test_03[:10]
# Out:
# array([1.1083614, 1.1088144, 1.1114353, 1.0280644, 0.9261294, 0.7850975,
#        0.9480385, 1.2325675, 0.8971322, 1.0467594], dtype=float32)

# %%
model.fit(X_train_scaled, y_train_04)
y_test_04 = model.predict(X_test_scaled)
y_test_04[:10]
# Out:
# array([14.214571, 13.404257, 14.582041, 15.269568, 14.680215, 15.635906,
#        16.180695, 14.548624, 15.114311, 14.942685], dtype=float32)

# %%
model.fit(X_train_scaled, y_train_05)
y_test_05 = model.predict(X_test_scaled)
y_test_05[:10]
# Out:
# array([32.56389 , 30.896824, 32.211475, 32.065987, 30.860197, 31.604315,
#        31.430656, 31.728651, 31.531712, 30.781345], dtype=float32)

# %%
model.fit(X_train_scaled, y_train_06)
y_test_06 = model.predict(X_test_scaled)
y_test_06[:10]
# Out:
# array([16.955965, 16.59268 , 17.01562 , 17.369532, 15.626993, 17.570633,
#        16.98524 , 17.236372, 17.158321, 17.03199 ], dtype=float32)

# %%
model.fit(X_train_scaled, y_train_07)
y_test_07 = model.predict(X_test_scaled)
y_test_07[:10]
# Out:
# array([2.9371858, 3.1786883, 3.0318754, 3.0732703, 3.0199153, 3.0302272,
#        2.8033862, 3.0764308, 3.0527303, 3.0087123], dtype=float32)

# %%
model.fit(X_train_scaled, y_train_08)
y_test_09 = model.predict(X_test_scaled)
y_test_09[:10]
# Out:
# array([-25.979033, -26.28014 , -26.173893, -25.652246, -25.660076,
#        -25.435143, -25.087116, -25.450417, -25.286665, -26.142841],
#       dtype=float32)

# %%
model.fit(X_train_scaled, y_train_09)
y_test_09 = model.predict(X_test_scaled)
y_test_09[:10]
# Out:
# array([-25.948797, -26.097713, -25.90643 , -25.438751, -25.661367,
#        -25.477432, -25.339098, -25.487295, -25.6546  , -25.99753 ],
#       dtype=float32)

# %%
model.fit(X_train_scaled, y_train_10)
y_test_10 = model.predict(X_test_scaled)
y_test_10[:10]
# Out:
# array([-22.00474 , -22.397602, -21.386656, -21.74462 , -21.96164 ,
#        -21.051935, -21.616087, -22.01806 , -21.506859, -22.7806  ],
#       dtype=float32)

# %%
model.fit(X_train_scaled, y_train_11)
y_test_11 = model.predict(X_test_scaled)
y_test_11[:10]
# Out:
# array([24.50069 , 24.148617, 24.283665, 25.510258, 24.877289, 25.182251,
#        25.088058, 24.915316, 25.162745, 24.273773], dtype=float32)

# %%
model.fit(X_train_scaled, y_train_12)
y_test_12 = model.predict(X_test_scaled)
y_test_12[:10]
# Out:
# array([-26.146717, -26.051853, -25.26614 , -25.400963, -25.683846,
#        -25.360409, -25.392025, -25.161486, -25.673986, -25.674982],
#       dtype=float32)

# %%
model.fit(X_train_scaled, y_train_13)
y_test_13 = model.predict(X_test_scaled)
y_test_13[:10]
# Out:
# array([-25.613201, -25.957207, -25.671175, -25.712221, -25.190046,
#        -25.446272, -25.337023, -25.40401 , -25.398304, -25.830976],
#       dtype=float32)

# %%
model.fit(X_train_scaled, y_train_14)
y_test_14 = model.predict(X_test_scaled)
y_test_14[:10]
# Out:
# array([-25.850468, -26.174938, -25.348408, -25.569662, -25.282299,
#        -25.233551, -25.072027, -25.420467, -25.590803, -25.683779],
#       dtype=float32)

# %%
y_test = pd.DataFrame([y_test_01, y_test_02, y_test_03, y_test_04, y_test_05,
                       y_test_06, y_test_07, y_test_08, y_test_09, y_test_10,
                       y_test_11, y_test_12, y_test_13, y_test_14])

# %%
y_test
# Out:
#         0          1          2          3          4          5      \
# 0    1.524816   1.493361   1.573775   1.444486   1.279378   1.542876
# 1    1.360828   1.206474   0.917671   1.095181   1.079400   0.997636
# 2    1.108361   1.108814   1.111435   1.028064   0.926129   0.785097
# 3   14.214571  13.404257  14.582041  15.269568  14.680215  15.635906
# 4   32.563889  30.896824  32.211475  32.065987  30.860197  31.604315
# 5   16.955965  16.592680  17.015619  17.369532  15.626993  17.570633
# 6    2.937186   3.178688   3.031875   3.073270   3.019915   3.030227
# 7  -25.979033 -26.280140 -26.173893 -25.652246 -25.660076 -25.435143
# 8  -25.948797 -26.097713 -25.906429 -25.438751 -25.661367 -25.477432
# 9  -22.004740 -22.397602 -21.386656 -21.744619 -21.961639 -21.051935
# 10  24.500690  24.148617  24.283665  25.510258  24.877289  25.182251
# 11 -26.146717 -26.051853 -25.266140 -25.400963 -25.683846 -25.360409
# 12 -25.613201 -25.957207 -25.671175 -25.712221 -25.190046 -25.446272
# ...

# %%
y_test.head()
# Out:
#        0          1          2          3          4          5      \
# 0   1.524816   1.493361   1.573775   1.444486   1.279378   1.542876
# 1   1.360828   1.206474   0.917671   1.095181   1.079400   0.997636
# 2   1.108361   1.108814   1.111435   1.028064   0.926129   0.785097
# 3  14.214571  13.404257  14.582041  15.269568  14.680215  15.635906
# 4  32.563889  30.896824  32.211475  32.065987  30.860197  31.604315
#
#        6          7          8          9      ...      39598      39599  \
# 0   1.330034   1.402138   1.336866   1.348331  ...   1.201740   1.202426
# 1   1.296090   1.408689   1.110380   0.897482  ...   0.921853   0.956106
# 2   0.948039   1.232568   0.897132   1.046759  ...   0.945411   0.979277
# 3  16.180695  14.548624  15.114311  14.942685  ...  12.365577  13.054276
# 4  31.430656  31.728651  31.531712  30.781345  ...  30.170639  30.164665
#
#        39600      39601      39602      39603      39604      39605  \
# ...

# %%
y_test.shape
# Out:
# (14, 39608)

# %%
y_test = y_test.T

# %%
y_test.shape
# Out:
# (39608, 14)

# %%
from sklearn.model_selection KFold, GridSearchCV
from xgboost import XGBClassifier

# %%
submit = pd.read_csv('./DACONLG/sample_submission.csv')

# %%
submit.shape
# Out:
# (39608, 15)

# %%
submit.columns
# Out:
# Index(['ID', 'Y_01', 'Y_02', 'Y_03', 'Y_04', 'Y_05', 'Y_06', 'Y_07', 'Y_08',
#        'Y_09', 'Y_10', 'Y_11', 'Y_12', 'Y_13', 'Y_14'],
#       dtype='object')

# %%
y_test[0]
# Out:
# 0        1.524816
# 1        1.493361
# 2        1.573775
# 3        1.444486
# 4        1.279378
#            ...
# 39603    1.278588
# 39604    1.284242
# 39605    1.206985
# 39606    1.058379
# 39607    1.412237
# Name: 0, Length: 39608, dtype: float32

# %%
for idx, col in enumerate(submit.columns):
    if col=='ID':
        continue
    submit[col] = y_test[idx-1]
print('Done.')
# Out:
# Done.

# %%
submit
# Out:
#                ID      Y_01      Y_02      Y_03       Y_04       Y_05  \
# 0      TEST_00001  1.524816  1.360828  1.108361  14.214571  32.563889
# 1      TEST_00002  1.493361  1.206474  1.108814  13.404257  30.896824
# 2      TEST_00003  1.573775  0.917671  1.111435  14.582041  32.211475
# 3      TEST_00004  1.444486  1.095181  1.028064  15.269568  32.065987
# 4      TEST_00005  1.279378  1.079400  0.926129  14.680215  30.860197
# ...           ...       ...       ...       ...        ...        ...
# 39603  TEST_39604  1.278588  1.102811  1.067046  12.328216  30.954681
# 39604  TEST_39605  1.284242  0.787210  0.916939  15.628615  31.576487
# 39605  TEST_39606  1.206985  0.877163  0.874098  12.858410  30.977749
# 39606  TEST_39607  1.058379  0.753721  0.854202  12.464704  31.331556
# 39607  TEST_39608  1.412237  0.755948  1.104917  12.913435  31.103477
#
#             Y_06      Y_07       Y_08       Y_09       Y_10       Y_11  \
# ...

# %%
submit.to_csv('./DACONLG/submit.csv', index=False)
